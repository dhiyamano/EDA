# %%
import pandas as pd

# Load dataset
df = pd.read_csv("cleaned_test.csv")

# Basic info
print("Shape of dataset:", df.shape)
print("\nData Info:\n")
print(df.info())

# Statistical summary
print("\nStatistical Summary:\n")
print(df.describe(include="all"))

# Value counts for categorical variables (if encoded, adjust accordingly)
for col in df.columns:
    if df[col].nunique() < 20:  # treat low-cardinality as categorical
        print(f"\nValue counts for {col}:\n", df[col].value_counts())
# Out:
# Shape of dataset: (418, 11)
#
# Data Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    float64
#  1   Pclass       418 non-null    float64
#  2   Name         418 non-null    float64
#  3   Sex          418 non-null    float64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    float64
#  6   Parch        418 non-null    float64
#  7   Ticket       418 non-null    float64
#  8   Fare         418 non-null    float64
#  9   Cabin        418 non-null    float64
#  10  Embarked     418 non-null    float64
# dtypes: float64(11)
# memory usage: 36.1 KB
# None
#
# Statistical Summary:
#
#        PassengerId        Pclass        Name           Sex           Age  \
# count   418.000000  4.180000e+02  418.000000  4.180000e+02  4.180000e+02
# mean      0.000000  1.487380e-17    0.000000  3.824692e-17  7.011935e-17
# std       1.001198  1.001198e+00    1.001198  1.001198e+00  1.001198e+00
# min      -1.727912 -1.505120e+00   -1.727912 -1.322876e+00 -2.319355e+00
# 25%      -0.863956 -1.505120e+00   -0.863956 -1.322876e+00 -5.200968e-01
# 50%       0.000000  8.734819e-01    0.000000  7.559289e-01 -2.048523e-01
# 75%       0.863956  8.734819e-01    0.863956  7.559289e-01  4.847449e-01
# max       1.727912  8.734819e-01    1.727912  7.559289e-01  3.656893e+00
#
#             SibSp         Parch        Ticket          Fare         Cabin  \
# count  418.000000  4.180000e+02  4.180000e+02  4.180000e+02  4.180000e+02
# mean     0.000000  1.699863e-17 -1.041166e-16  9.561729e-17  3.824692e-17
# std      1.001198  1.001198e+00  1.001198e+00  1.001198e+00  1.001198e+00
# min     -0.499470 -4.002477e-01 -1.684697e+00 -6.377637e-01 -1.469059e+00
# 25%     -0.499470 -4.002477e-01 -8.909727e-01 -4.962194e-01 -3.514904e-01
# 50%     -0.499470 -4.002477e-01  5.123029e-04 -3.786501e-01 -3.514904e-01
# 75%      0.616992 -4.002477e-01  9.199290e-01 -7.358230e-02 -3.514904e-01
# max      8.432229  8.781044e+00  1.685722e+00  8.546519e+00  4.118784e+00
#
#            Embarked
# count  4.180000e+02
# mean  -1.444884e-16
# std    1.001198e+00
# min   -1.642598e+00
# 25%   -4.709154e-01
# 50%    7.007669e-01
# 75%    7.007669e-01
# max    7.007669e-01
#
# Value counts for Pclass:
#  Pclass
#  0.873482    218
# -1.505120    107
# -0.315819     93
# Name: count, dtype: int64
#
# Value counts for Sex:
#  Sex
#  0.755929    266
# -1.322876    152
# Name: count, dtype: int64
#
# Value counts for SibSp:
#  SibSp
# -0.499470    283
#  0.616992    110
#  1.733455     14
#  2.849917      4
#  3.966380      4
#  8.432229      2
#  5.082842      1
# Name: count, dtype: int64
#
# Value counts for Parch:
#  Parch
# -0.400248    324
#  0.619896     52
#  1.640039     33
#  2.660183      3
#  3.680326      2
#  8.781044      2
#  5.720613      1
#  4.700470      1
# Name: count, dtype: int64
#
# Value counts for Embarked:
#  Embarked
#  0.700767    270
# -1.642598    102
# -0.470915     46
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pairplot
sns.pairplot(df.sample(min(200, len(df))))  # sample to avoid heavy plotting
plt.suptitle("Pairplot of Features", y=1.02)
plt.show()

# Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Correlation matrix values
corr_matrix = df.corr()
print("\nCorrelation Matrix:\n", corr_matrix)

# Example: check top correlations with Fare
print("\nTop correlations with Fare:\n", corr_matrix["Fare"].sort_values(ascending=False))
# Out:
# Correlation Matrix:
#               PassengerId    Pclass      Name       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.026751  0.042079  0.023245 -0.031447  0.003818
# Pclass         -0.026751  1.000000  0.038918  0.108615 -0.467853  0.001087
# Name            0.042079  0.038918  1.000000  0.067263 -0.032388  0.043994
# Sex             0.023245  0.108615  0.067263  1.000000 -0.008035 -0.099943
# Age            -0.031447 -0.467853 -0.032388 -0.008035  1.000000 -0.071197
# SibSp           0.003818  0.001087  0.043994 -0.099943 -0.071197  1.000000
# Parch           0.043080  0.018721 -0.010295 -0.159120 -0.043731  0.306895
# Ticket         -0.012301  0.292088  0.025531 -0.047663 -0.132918  0.025199
# Fare            0.008633 -0.577313 -0.018802 -0.192036  0.342357  0.171912
# Cabin           0.029253 -0.357330 -0.026371 -0.064809  0.135714  0.023042
# Embarked        0.040699  0.227983 -0.081444  0.076281 -0.148051  0.052708
#
#                 Parch    Ticket      Fare     Cabin  Embarked
# PassengerId  0.043080 -0.012301  0.008633  0.029253  0.040699
# Pclass       0.018721  0.292088 -0.577313 -0.357330  0.227983
# Name        -0.010295  0.025531 -0.018802 -0.026371 -0.081444
# Sex         -0.159120 -0.047663 -0.192036 -0.064809  0.076281
# Age         -0.043731 -0.132918  0.342357  0.135714 -0.148051
# SibSp        0.306895  0.025199  0.171912  0.023042  0.052708
# Parch        1.000000  0.109888  0.230325  0.005145  0.054577
# Ticket       0.109888  1.000000 -0.019401 -0.169111  0.093672
# Fare         0.230325 -0.019401  1.000000  0.235845 -0.257624
# Cabin        0.005145 -0.169111  0.235845  1.000000 -0.179306
# Embarked     0.054577  0.093672 -0.257624 -0.179306  1.000000
#
# Top correlations with Fare:
#  Fare           1.000000
# Age            0.342357
# Cabin          0.235845
# Parch          0.230325
# SibSp          0.171912
# PassengerId    0.008633
# Name          -0.018802
# Ticket        -0.019401
# Sex           -0.192036
# Embarked      -0.257624
# Pclass        -0.577313
# Name: Fare, dtype: float64

# %%
# Histograms
df.hist(bins=30, figsize=(15,10))
plt.suptitle("Histograms of Numerical Features")
plt.show()

# Boxplots
for col in df.columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# Scatterplots (example with key features)
sns.scatterplot(x="Pclass", y="Fare", data=df)
plt.title("Scatterplot of Pclass vs Fare")
plt.show()

sns.scatterplot(x="Age", y="Fare", data=df)
plt.title("Scatterplot of Age vs Fare")
plt.show()
